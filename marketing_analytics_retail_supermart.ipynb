# %% [markdown]
# # Retail Supermarket Analysis

# %% [markdown]
# # **Masterclass on Marketing Analytics**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://www.dropbox.com/scl/fi/y8fjteq67psqf177lvjz7/retailData.csv?rlkey=bs6x9udsrevc2369ibades77h -O 'retailData.csv'
# Out:
# --2024-06-18 07:33:06--  https://www.dropbox.com/scl/fi/y8fjteq67psqf177lvjz7/retailData.csv?rlkey=bs6x9udsrevc2369ibades77h
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com/cd/0/inline/CVB2z-9xgUj18BIn0yATTip-BQDmXRko6G4xmjrED-9w3VIGg2yJfzeIWCEnbbpZ_-5iXX9_EfHCMcfYYkmS__L8nxcMtmWf791t1Iwy29O8iDpxMu2c1H09rZQBxp8M_y-Pp76S3AZCY33-7sIbSrG9/file# [following]
# --2024-06-18 07:33:06--  https://uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com/cd/0/inline/CVB2z-9xgUj18BIn0yATTip-BQDmXRko6G4xmjrED-9w3VIGg2yJfzeIWCEnbbpZ_-5iXX9_EfHCMcfYYkmS__L8nxcMtmWf791t1Iwy29O8iDpxMu2c1H09rZQBxp8M_y-Pp76S3AZCY33-7sIbSrG9/file
# Resolving uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com (uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com (uc4d7a7b3418a2362524a03f12e5.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1113007 (1.1M) [text/plain]
# Saving to: ‘retailData.csv’
#
# retailData.csv      100%[===================>]   1.06M  --.-KB/s    in 0.1s
#
# 2024-06-18 07:33:07 (8.58 MB/s) - ‘retailData.csv’ saved [1113007/1113007]

# %%
# reading csv file
df = pd.read_csv("retailData.csv")
df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
# rows and cols
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# check for the Missing Values.
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# deleting the column
df.drop(["Country", "Postal Code"], axis=1, inplace= True)

# %%
# a = df.drop(["Country", "Postal Code"], axis=1)

# %%
# first 5 rows
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
# types of shipping mode
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
# viz
df['Ship Mode'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Segment'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Category'].value_counts(normalize=True)
# Out:
# Office Supplies    0.602962
# Furniture          0.212227
# Technology         0.184811
# Name: Category, dtype: float64

# %%
df['Category'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# - office supllies has a major part(60%) in all the transcation.

# %%
df['Sub-Category'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data = df, x = 'Sales')
plt.xlim(0, 500);

# %%
## filtering the data to capture sales with over 10000 USD txn
df[df['Sales']> 10000]
# Out:
#            Ship Mode      Segment           City       State   Region  \
# 2623     First Class  Home Office  New York City    New York     East
# 2697  Standard Class  Home Office   Jacksonville     Florida    South
# 4190  Standard Class     Consumer         Newark    Delaware     East
# 6826  Standard Class    Corporate      Lafayette     Indiana  Central
# 8153     First Class     Consumer        Seattle  Washington     West
#
#         Category Sub-Category      Sales  Quantity  Discount     Profit
# 2623  Technology      Copiers  11199.968         4       0.2  3919.9888
# 2697  Technology     Machines  22638.480         6       0.5 -1811.0784
# 4190  Technology      Copiers  10499.970         3       0.0  5039.9856
# 6826  Technology      Copiers  17499.950         5       0.0  8399.9760
# 8153  Technology      Copiers  13999.960         4       0.0  6719.9808

# %%
sns.histplot(data = df, x = 'Profit')ˀ
plt.xlim(-200, 200);

# %%
sns.histplot(data = df, x = 'Discount',bins = 20);

# %% [markdown]
# ## BoxPlot

# %%
sns.boxplot(data = df, y = 'Sales', x = 'Category');

# %%
plt.figure(figsize = (6, 20))
sns.boxplot(data = df, y = 'Sales', x = 'Category');

# %%
plt.figure(figsize = (6, 20))
sns.boxplot(data = df, y = 'Profit', x = 'Category');

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.head()

# %% [markdown]
# ## Grouping

# %%
city_profit = df.groupby("City")['Profit'].sum().sort_values(ascending=False).reset_index()[:10]
city_profit
# Out:
#             City      Profit
# 0  New York City  62036.9837
# 1    Los Angeles  30440.7579
# 2        Seattle  29156.0967
# 3  San Francisco  17507.3854
# 4        Detroit  13181.7908
# 5      Lafayette  10018.3876
# 6        Jackson   7581.6828
# 7        Atlanta   6993.6629
# 8    Minneapolis   6824.5846
# 9      San Diego   6377.1960

# %%
sns.barplot(data = city_profit, y = 'City', x= 'Profit');

# %%
plt.figure(figsize=(10, 8))

state_profit = df.groupby("State")['Profit'].sum().sort_values(ascending=False).reset_index()

sns.barplot(data = state_profit, y = 'State', x= 'Profit');

# %%
state_info = df.groupby("State")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)[:10]
state_info
# Out:
#                     Sales      Profit
# State
# California    457687.6315  76381.3871
# New York      310876.2710  74038.5486
# Texas         170188.0458 -25729.3563
# Washington    138641.2700  33402.6517
# Pennsylvania  116511.9140 -15559.9603
# Florida        89473.7080  -3399.3017
# Illinois       80166.1010 -12607.8870
# Ohio           78258.1360 -16971.3766
# Michigan       76269.6140  24463.1876
# Virginia       70636.7200  18597.9504

# %%
state_info.plot.bar(color = ["Green","Red"], figsize=(12,6))
# Out:
# <Axes: xlabel='State'>

# %%
region_info = df.groupby("Region")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
region_info
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303

# %%
region_info.plot.bar(color = ["Green","Red"], figsize=(12,6))
# Out:
# <Axes: xlabel='Region'>

# %%
# Category wise Sales.

sns.barplot(data = df, y = 'Sales', x= 'Category')
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
# Categories wise Profit.
sns.barplot(data = df, y = 'Profit', x= 'Category')
# Out:
# <Axes: xlabel='Category', ylabel='Profit'>

# %%
sub_category = df.groupby('Sub-Category')['Profit'].sum().sort_values().reset_index()
sub_category[:10]
# Out:
#   Sub-Category      Profit
# 0       Tables -17725.4811
# 1    Bookcases  -3472.5560
# 2     Supplies  -1189.0995
# 3    Fasteners    949.5182
# 4     Machines   3384.7569
# 5       Labels   5546.2540
# 6          Art   6527.7870
# 7    Envelopes   6964.1767
# 8  Furnishings  13059.1436
# 9   Appliances  18138.0054

# %%
sns.barplot(data=sub_category, x='Sub-Category', y='Profit')
plt.xticks(rotation = 90)
plt.title('Profit by Sub-Category');

# %%
sns.lineplot(data=df, x="Discount", y= "Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# # Future Scope:
# - customer information
# - product wise sales.
# - upcoming events
# - competitor analysis

# %%
# RCA -> root cause analysis.

# %%
texas = df[df['State'] == 'Texas']
texas.head(5)
# Out:
#          Ship Mode      Segment        Country        City  State  \
# 14  Standard Class  Home Office  United States  Fort Worth  Texas
# 15  Standard Class  Home Office  United States  Fort Worth  Texas
# 34    Second Class  Home Office  United States     Houston  Texas
# 35     First Class    Corporate  United States  Richardson  Texas
# 36     First Class    Corporate  United States  Richardson  Texas
#
#     Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 14        76106  Central  Office Supplies   Appliances    68.810         5
# 15        76106  Central  Office Supplies      Binders     2.544         3
# 34        77095  Central  Office Supplies        Paper    29.472         3
# 35        75080  Central       Technology       Phones  1097.544         7
# 36        75080  Central        Furniture  Furnishings   190.920         5
#
#     Discount    Profit
# 14       0.8 -123.8580
# 15       0.8   -3.8160
# 34       0.2    9.9468
# 35       0.2  123.4737
# 36       0.6 -147.9630

# %%
texas['Sub-Category'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sub-Category'>
